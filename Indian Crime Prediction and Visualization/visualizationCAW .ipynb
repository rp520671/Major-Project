# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML

import pandas as pd

# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML

import pandas as pd

init_notebook_mode(connected=True)

url = 'https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv'
dataset = pd.read_csv(url)

years = ['1952', '1962', '1967', '1972', '1977', '1982', '1987', '1992', '1997', '2002', '2007']
# make list of continents
continents = []
for continent in dataset['continent']:
    if continent not in continents:
        continents.append(continent)
# make figure
figure = {
    'data': [],
    'layout': {},
    'frames': []
}

# fill in most of layout
figure['layout']['xaxis'] = {'range': [30, 85], 'title': 'Life Expectancy'}
figure['layout']['yaxis'] = {'title': 'GDP per Capita', 'type': 'log'}
figure['layout']['hovermode'] = 'closest'
figure['layout']['sliders'] = {
    'args': [
        'transition', {
            'duration': 400,
            'easing': 'cubic-in-out'
        }
    ],
    'initialValue': '1952',
    'plotlycommand': 'animate',
    'values': years,
    'visible': True
}
figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]

sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

# make data
year = 1952
for continent in continents:
    dataset_by_year = dataset[dataset['year'] == year]
    dataset_by_year_and_cont = dataset_by_year[dataset_by_year['continent'] == continent]

    data_dict = {
        'x': list(dataset_by_year_and_cont['lifeExp']),
        'y': list(dataset_by_year_and_cont['gdpPercap']),
        'mode': 'markers',
        'text': list(dataset_by_year_and_cont['country']),
        'marker': {
            'sizemode': 'area',
            'sizeref': 200000,
            'size': list(dataset_by_year_and_cont['pop'])
        },
        'name': continent
    }
    figure['data'].append(data_dict)
    
# make frames
for year in years:
    frame = {'data': [], 'name': str(year)}
    for continent in continents:
        dataset_by_year = dataset[dataset['year'] == int(year)]
        dataset_by_year_and_cont = dataset_by_year[dataset_by_year['continent'] == continent]

        data_dict = {
            'x': list(dataset_by_year_and_cont['lifeExp']),
            'y': list(dataset_by_year_and_cont['gdpPercap']),
            'mode': 'markers',
            'text': list(dataset_by_year_and_cont['country']),
            'marker': {
                'sizemode': 'area',
                'sizeref': 200000,
                'size': list(dataset_by_year_and_cont['pop'])
            },
            'name': continent
        }
        frame['data'].append(data_dict)

    figure['frames'].append(frame)
    slider_step = {'args': [
        [year],
        {'frame': {'duration': 300, 'redraw': False},
         'mode': 'immediate',
       'transition': {'duration': 300}}
     ],
     'label': year,
     'method': 'animate'}
    sliders_dict['steps'].append(slider_step)

    
figure['layout']['sliders'] = [sliders_dict]

iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
import chart_studio.plotly as py
from chart_studio.grid_objs import Grid, Column

import time

column_1 = Column([0.5], 'x')
column_2 = Column([0.5], 'y')
column_3 = Column([1.5], 'x2')
column_4 = Column([1.5], 'y2')

grid = Grid([column_1, column_2, column_3, column_4])
py.grid_ops.upload(grid, 'ping_pong_grid'+str(time.time()), auto_open=False)

figure = {
    'data': [
        {
            'xsrc': grid.get_column_reference('x'),
            'ysrc': grid.get_column_reference('y'),
            'mode': 'markers',
        }
    ],
    'layout': {'title': 'Ping Pong Animation',
               'xaxis': {'range': [0, 2], 'autorange': False},
               'yaxis': {'range': [0, 2], 'autorange': False},
               'updatemenus': [{
                   'buttons': [
                       {'args': [None],
                        'label': 'Play',
                        'method': 'animate'}
               ],
               'pad': {'r': 10, 't': 87},
               'showactive': False,
               'type': 'buttons'
                }]},
    'frames': [
        {
            'data': [
                {
                    'xsrc': grid.get_column_reference('x2'),
                    'ysrc': grid.get_column_reference('y2'),
                    'mode': 'markers',
                }
            ]
        },
        {
            'data': [
                {
                    'xsrc': grid.get_column_reference('x'),
                    'ysrc': grid.get_column_reference('y'),
                    'mode': 'markers',
                }
            ]
        }
    ]
}

py.icreate_animations(figure, 'ping_pong'+str(time.time()))
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24348\1909660660.py in <module>
#      10
#      11 grid = Grid([column_1, column_2, column_3, column_4])
# ---> 12 py.grid_ops.upload(grid, 'ping_pong_grid'+str(time.time()), auto_open=False)
#      13
#      14 figure = {
#
# ~\AppData\Roaming\Python\Python39\site-packages\chart_studio\plotly\plotly.py in upload(cls, grid, filename, world_readable, auto_open, meta)
#    1085                 payload["parent_path"] = parent_path
#    1086
# -> 1087         file_info = _create_or_overwrite_grid(payload)
#    1088
#    1089         cols = file_info["cols"]
#
# ~\AppData\Roaming\Python\Python39\site-packages\chart_studio\plotly\plotly.py in _create_or_overwrite_grid(data, max_retries)
#    1548     # Create file
#    1549     try:
# -> 1550         res = api_module.create(data)
# ...

# %%
import pandas as pd
import numpy as np

summ = 0
df = pd.read_csv('/rp960/Documents/Jupyter/Indian-Crime-Prediction-and-Visualization-Online-Platform-master/static/dataset/StateWiseCAW01_15.csv', names=["STATE/UT","Rape","Kidnapping and Abduction","Dowry Deaths","Assault on women with intent to outrage her modesty","Insult to modesty of Women","Cruelty by Husband or his Relatives","Importation of Girls"])
df['Total'] = df.sum(axis=1)
with open("/home/shivam/BE_Project/BE_Project/static/final.csv", 'wb') as f:
    df.to_csv(f, header = True)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('C:/Users/rp960/Documents/Jupyter/Indian-Crime-Prediction-and-Visualization-Online-Platform-master/static/dataset/StateWiseCAW01_15.csv')
datF = df[df['DISTRICT'] == 'TOTAL']
print(datF['DISTRICT'])
datF.to_csv('C:/Users/rp960/Documents/Jupyter/Indian-Crime-Prediction-and-Visualization-Online-Platform-master/static/StateWiseCAW2001_15.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DISTRICT'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/population2001_11.csv", names = ["State_UT","Population_Persons_2001","Population_Persons_2011","Number_of_literates_Persons_2001","Number_of_literates_Persons_2011"])
#cdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/StateCAW2001_15.csv", names = ["STATE_UT","Year","Rape","Kidnapping_and_Abduction","Dowry_Deaths","Assault_on_women_with_intent_to_outrage_her_modesty","Insult_to_modesty_of_Women","Cruelty_by_Husband_or_his_Relatives","Importation_of_Girls","Total"])
print pdf
pdatf = (pdf["Population_Persons_2011"] - pdf["Population_Persons_2001"])/10
pdf['diffPop'] = pdatf
pdatf = (pdf["Number_of_literates_Persons_2011"] - pdf["Number_of_literates_Persons_2001"])/10
pdf['diffLitracy'] = pdatf
pdf.to_csv("/home/shivam/BE_Project/BE_Project/static/Population2001_11.csv")
# Out:
#                        State_UT  Population_Persons_2001  \
# 0             JAMMU AND KASHMIR                 10143700
# 1              HIMACHAL PRADESH                  6077900
# 2                        PUNJAB                 24358999
# 3                    CHANDIGARH                   900635
# 4                   UTTARAKHAND                  8489349
# 5                       HARYANA                 21144564
# 6                         DELHI                 13850507
# 7                     RAJASTHAN                 56507188
# 8                 UTTAR PRADESH                166197921
# 9                         BIHAR                 82998509
# 10                       SIKKIM                   540851
# 11            ARUNACHAL PRADESH                  1097968
# 12                     NAGALAND                  1990036
# 13                      MANIPUR                  2166788
# 14                      MIZORAM                   888573
# ...

# %%
pdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/population2001_11.csv")

pdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf6e804e3a22> in <module>()
#       1
# ----> 2 pdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/population2001_11.csv")
#       3
#       4 pdf
#       5
#
# NameError: name 'pd' is not defined

# %%
pdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/population2001_11.csv")
cdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/StateCAW2001_15.csv")

print pdf.head()
print cdf.head()
# Out:
#             State_UT  Population_Persons_2001  Population_Persons_2011  \
# 0  JAMMU AND KASHMIR                 10143700                 12548926
# 1   HIMACHAL PRADESH                  6077900                  6856509
# 2             PUNJAB                 24358999                 27704236
# 3         CHANDIGARH                   900635                  1054686
# 4        UTTARAKHAND                  8489349                 10116752
#
#    Number_of_literates_Persons_2001  Number_of_literates_Persons_2011  \
# 0                           4807286                           7245053
# 1                           4041621                           5104506
# 2                          14756970                          18988611
# 3                            643245                            809653
# 4                           5105782                           6997433
#
#     diffPop  diffLitracy
# 0  240522.6     243776.7
# 1   77860.9     106288.5
# 2  334523.7     423164.1
# ...

# %%
pdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/Population2001_11.csv")
cdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/final.csv")




for j in pdf.iloc[:,:].values:
    state = j[0]
    pop_01 = j[1]
    PopDiff = j[5]
    LitDiff = j[6]
    Lit_01 = j[3]
    
    for i in range(2001, 2016):
        list = np.array([])
        
        list = np.append(list,state)
        
        list = np.append(list,i)
        

        
        offset = (i - 2001)*PopDiff
        pop = pop_01 + offset
        print pop
        list = np.append(list,pop)
        
        offset = (i - 2001)*LitDiff
        Lit = Lit_01 + offset
        Lit_per = (Lit)
        list = np.append(list,Lit_per)
        
        data1 = cdf.loc[cdf["STATE/UT"]==state].values
 
        for x in data1:
            if x[1] == i:
                test = x
                break
        print test[9]
        CrimePerPop = (test[9]/pop)*100000
        list = np.append(list,CrimePerPop)
        datf = pd.DataFrame(list)
        datf = datf.transpose()
        datf = datf.iloc[0,:].values
        df = pd.DataFrame(datf,index=None, columns=None).transpose()
        print df.head()
        df.to_csv("/home/shivam/BE_Project/BE_Project/static/test11.csv", mode='a', header=False)

"""
summ = 0
df = pd.read_csv('/home/shivam/BE_Project/BE_Project/static/hope (copy).csv')
df['Total'] = df.sum(axis=1)
with open("/home/shivam/BE_Project/BE_Project/static/final.csv", 'wb') as f:
    df.to_csv(f, header = True)"""

# %%
pdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/population2001_11.csv")
cdf = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/StateCAW2001_15.csv")




for j in pdf.loc[cdf["STATE_UT"]=="ODISHA"].values:
    state = j[0]
    pop_01 = j[1]
    PopDiff = j[5]
    LitDiff = j[6]
    Lit_01 = j[3]

    for i in range(2001, 2016):
        list = np.array([])
        
        list = np.append(list,state)
        
        list = np.append(list,i)
        

        
        offset = (i - 2001)*PopDiff
        pop = pop_01 + offset
        list = np.append(list,pop)
        
        offset = (i - 2001)*LitDiff
        Lit = Lit_01 + offset
        Lit_per = (Lit/pop)*100
        list = np.append(list,Lit_per)
        print list
        print pop
        print Lit
        data1 = cdf.loc[cdf["STATE_UT"]==state].values
        for x in data1:
            if x[1] == i:
                test = x
                break
        print test
# Out:
# ['ODISHA' '2001' '36804660.0' '538.982158781']
# 36804660.0
# 198370551.0
# ['ODISHA' 2001 790 434 294 1655 458 1266 0 6898]
# ['ODISHA' '2002' '37318929.8' '485.66433837']
# 37318929.8
# 181244733.5
# ['ODISHA' 2002 691 432 248 1605 188 1167 0 6333]
# ['ODISHA' '2003' '37833199.6' '433.796025013']
# 37833199.6
# 164118916.0
# ['ODISHA' 2003 725 373 279 1669 188 1289 0 6526]
# ['ODISHA' '2004' '38347469.4' '383.318901612']
# 38347469.4
# 146993098.5
# ['ODISHA' 2004 770 423 319 1811 170 1192 0 6689]
# ['ODISHA' '2005' '38861739.2' '334.177737985']
# 38861739.2
# 129867281.0
# ['ODISHA' 2005 799 547 334 2238 184 1671 0 7778]
# ['ODISHA' '2006' '39376009.0' '286.320189281']
# 39376009.0
# 112741463.5
# ['ODISHA' 2006 985 577 457 2415 247 694 12 7393]
# ['ODISHA' '2007' '39890278.8' '239.696609992']
# 39890278.8
# 95615646.0
# ['ODISHA' 2007 939 660 461 2775 241 728 0 7811]
# ['ODISHA' '2008' '40404548.6' '194.259882166']
# 40404548.6
# 78489828.5
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/home/shivam/BE_Project/BE_Project/static/PlotlyFile(final).csv")
'''print max(df['gdpPercap'])
print min(df['gdpPercap'])'''
a = (max(df['gdpPercap'])-min(df['gdpPercap']))/5
print a
arr = np.array([])
val = np.array([])
r = 0 
for j in df.iloc[:,5].values:
    arr= np.append(arr,j)   

for i in range(511,525):
    if(arr[i] <= a):
        print arr[i]
        val = np.append(val,'Lowest Crime')
    elif(arr[i]>a and arr[i]<=a*2):
        print arr[i]
        val = np.append(val,'Low Crime')
    elif(arr[i]>a and arr[i]<=a*2):
        print arr[i]
        val = np.append(val,'Medium Crime')
    elif(arr[i]>a*3 and arr[i]<=a*4):
        print arr[i]
        val = np.append(val,'Slightly High Crime')
    elif(arr[i]>a*4):
        print arr[i]
        val = np.append(val,'Hightest Crime')
#print len(val)
df['Group'] = pd.DataFrame(val, index=None, columns=None)
print df['Group']
#df.to_csv("/home/shivam/BE_Project/BE_Project/static/waah.csv", mode='a', header=True)
# Out:
# 18.9814563051
# 7.5307253595
# 6.0956957738
# 7.4320872384
# 6.0163732864
# 9.7813328696
# 14.577763188
# 21.4588590754
# 24.2546622258
# 21.718126266
# 12.6334407176
# 12.2932639191
# 12.2172359725
# 12.1421426387
# 34.1497783602
# 0      Lowest Crime
# 1      Lowest Crime
# 2      Lowest Crime
# 3      Lowest Crime
# 4      Lowest Crime
# 5      Lowest Crime
# 6         Low Crime
# 7         Low Crime
# 8         Low Crime
# 9      Lowest Crime
# 10     Lowest Crime
# 11     Lowest Crime
# 12     Lowest Crime
# 13        Low Crime
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
#            ...
# 495             NaN
# 496             NaN
# 497             NaN
# 498             NaN
# ...

# %%
import pandas as pd
df = pd.read_csv("/home/shivam/Downloads/Statewise Cases Reported of  SLL Crimes Committed 1972-2016.csv")
# Out:
# NoneType
